# %% [markdown]
# # Ungraded Lab: Data Augmentation
#
# In the previous lessons, you saw that having a high training accuracy does not automatically mean having a good predictive model. It can still perform poorly on new data because it has overfit to the training set. In this lab, you will see how to avoid that using _data augmentation_. This increases the amount of training data by modifying the existing training data's properties. For example, in image data, you can apply different preprocessing techniques such as rotate, flip, shear, or zoom on your existing images so you can simulate other data that the model should also learn from. This way, the model would see more variety in the images during training so it will infer better on new, previously unseen data.
#
# Let's see how you can do this in the following sections.

# %% [markdown]
# ## Baseline Performance
#
# You will start with a model that's very effective at learning `Cats vs Dogs` without data augmentation. It's similar to the previous models that you have used. Note that there are four convolutional layers with 32, 64, 128 and 128 convolutions respectively. The code is basically the same from the previous lab so we won't go over the details step by step since you've already seen it before.

# %%
# First import the necessary libraries
import os
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
BASE_DIR = 'cats_and_dogs_filtered'

train_dir = os.path.join(BASE_DIR, 'train')
validation_dir = os.path.join(BASE_DIR, 'validation')

# Directory with training cat/dog pictures
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with validation cat/dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

print(f"Contents of base directory: {os.listdir(BASE_DIR)}")

print(f"\nContents of train directory: {os.listdir(train_dir)}")

print(f"\nContents of validation directory: {os.listdir(validation_dir)}")
# Out:
# Contents of base directory: ['train', 'validation']
#
# Contents of train directory: ['dogs', 'cats']
#
# Contents of validation directory: ['dogs', 'cats']

# %% [markdown]
# You will place the model creation inside a function so you can easily initialize a new one when you use data augmentation later in this notebook.

# %%
def create_model():
    '''Creates a CNN with 4 convolutional layers'''
    model = tf.keras.models.Sequential([
        tf.keras.Input(shape=(150, 150, 3)),
        tf.keras.layers.Rescaling(1./255),
        tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    return model

# %% [markdown]
# You will preprocess the training and validation datasets as usual.

# %%
# Instantiate the training dataset
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(150, 150),
    batch_size=20,
    label_mode='binary'
    )

# Instantiate the validation dataset
validation_dataset = tf.keras.utils.image_dataset_from_directory(
    validation_dir,
    image_size=(150, 150),
    batch_size=20,
    label_mode='binary'
    )

# Optimize the datasets for training
SHUFFLE_BUFFER_SIZE = 1000
PREFETCH_BUFFER_SIZE = tf.data.AUTOTUNE

train_dataset_final = (train_dataset
                       .cache()
                       .shuffle(SHUFFLE_BUFFER_SIZE)
                       .prefetch(PREFETCH_BUFFER_SIZE)
                       )

validation_dataset_final = (validation_dataset
                            .cache()
                            .prefetch(PREFETCH_BUFFER_SIZE)
                            )
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.

# %% [markdown]
# You will train only for 20 epochs to save time but feel free to increase this if you want.

# %%
# Constant for epochs
EPOCHS = 20

# Create a new model
model = create_model()

# Setup the training parameters
model.compile(loss='binary_crossentropy',
              optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
              metrics=['accuracy'])

# Train the model
history = model.fit(
      train_dataset_final,
      epochs=EPOCHS,
      validation_data=validation_dataset_final,
      verbose=2)
# Out:
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1737402349.703392     276 service.cc:145] XLA service 0x77cbd00034a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1737402349.703516     276 service.cc:153]   StreamExecutor device (0): NVIDIA A10G, Compute Capability 8.6
# I0000 00:00:1737402352.113230     276 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 100/100 - 6s - 64ms/step - accuracy: 0.5280 - loss: 0.6917 - val_accuracy: 0.5650 - val_loss: 0.6800
# Epoch 2/20
# 100/100 - 1s - 7ms/step - accuracy: 0.5770 - loss: 0.6772 - val_accuracy: 0.5400 - val_loss: 0.6873
# Epoch 3/20
# 100/100 - 1s - 7ms/step - accuracy: 0.6215 - loss: 0.6498 - val_accuracy: 0.6570 - val_loss: 0.6304
# Epoch 4/20
# 100/100 - 1s - 7ms/step - accuracy: 0.6470 - loss: 0.6233 - val_accuracy: 0.6700 - val_loss: 0.6113
# Epoch 5/20
# 100/100 - 1s - 7ms/step - accuracy: 0.6755 - loss: 0.5902 - val_accuracy: 0.6770 - val_loss: 0.5965
# Epoch 6/20
# 100/100 - 1s - 7ms/step - accuracy: 0.7085 - loss: 0.5636 - val_accuracy: 0.6990 - val_loss: 0.5898
# Epoch 7/20
# 100/100 - 1s - 7ms/step - accuracy: 0.7255 - loss: 0.5475 - val_accuracy: 0.6930 - val_loss: 0.5852
# Epoch 8/20
# 100/100 - 1s - 7ms/step - accuracy: 0.7320 - loss: 0.5318 - val_accuracy: 0.6900 - val_loss: 0.5936
# Epoch 9/20
# 100/100 - 1s - 7ms/step - accuracy: 0.7460 - loss: 0.5112 - val_accuracy: 0.7030 - val_loss: 0.5726
# Epoch 10/20
# 100/100 - 1s - 7ms/step - accuracy: 0.7585 - loss: 0.4877 - val_accuracy: 0.6990 - val_loss: 0.5727
# Epoch 11/20
# 100/100 - 1s - 7ms/step - accuracy: 0.7835 - loss: 0.4696 - val_accuracy: 0.6890 - val_loss: 0.5874
# Epoch 12/20
# 100/100 - 1s - 7ms/step - accuracy: 0.7810 - loss: 0.4483 - val_accuracy: 0.7000 - val_loss: 0.5715
# Epoch 13/20
# 100/100 - 1s - 7ms/step - accuracy: 0.8040 - loss: 0.4292 - val_accuracy: 0.7150 - val_loss: 0.5548
# Epoch 14/20
# 100/100 - 1s - 7ms/step - accuracy: 0.8170 - loss: 0.4009 - val_accuracy: 0.7400 - val_loss: 0.5378
# Epoch 15/20
# 100/100 - 1s - 7ms/step - accuracy: 0.8270 - loss: 0.3848 - val_accuracy: 0.7110 - val_loss: 0.5658
# Epoch 16/20
# 100/100 - 1s - 7ms/step - accuracy: 0.8400 - loss: 0.3677 - val_accuracy: 0.7320 - val_loss: 0.5444
# Epoch 17/20
# 100/100 - 1s - 7ms/step - accuracy: 0.8645 - loss: 0.3439 - val_accuracy: 0.7130 - val_loss: 0.6086
# Epoch 18/20
# 100/100 - 1s - 7ms/step - accuracy: 0.8630 - loss: 0.3264 - val_accuracy: 0.7150 - val_loss: 0.5989
# Epoch 19/20
# 100/100 - 1s - 7ms/step - accuracy: 0.8755 - loss: 0.3039 - val_accuracy: 0.7040 - val_loss: 0.6527
# Epoch 20/20
# 100/100 - 1s - 7ms/step - accuracy: 0.8810 - loss: 0.2859 - val_accuracy: 0.7490 - val_loss: 0.5720

# %% [markdown]
# You will then visualize the loss and accuracy with respect to the training and validation set. You will again use a convenience function so it can be reused later. This function accepts a [History](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/History) object which contains the results of the `fit()` method you ran above.

# %%
def plot_loss_acc(history):
    '''Plots the training and validation loss and accuracy from a history object'''
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    fig, ax = plt.subplots(1,2, figsize=(12, 6))
    ax[0].plot(epochs, acc, 'bo', label='Training accuracy')
    ax[0].plot(epochs, val_acc, 'b', label='Validation accuracy')
    ax[0].set_title('Training and validation accuracy')
    ax[0].set_xlabel('epochs')
    ax[0].set_ylabel('accuracy')
    ax[0].legend()

    ax[1].plot(epochs, loss, 'bo', label='Training Loss')
    ax[1].plot(epochs, val_loss, 'b', label='Validation Loss')
    ax[1].set_title('Training and validation loss')
    ax[1].set_xlabel('epochs')
    ax[1].set_ylabel('loss')
    ax[1].legend()

    plt.show()

# %%
# Plot training results
plot_loss_acc(history)

# %% [markdown]
# From the results above, you'll see the training accuracy is more than 90%, and the validation accuracy is in the 70%-80% range. This is a great example of _overfitting_ -- which in short means that it can do very well with images it has seen before, but not so well with images it hasn't.

# %% [markdown]
# ## Data augmentation
#
# One simple method to avoid overfitting is to augment the images. If you think about it, most pictures of a cat are very similar -- the ears are at the top, the eyes are below the ears etc. Things like the distance between the eyes and ears will always be quite similar too.
#
# What if you tweak with the images a bit -- rotate the image, squash it, etc.  That's what image augementation is all about.
#
# To do that, you will build a data augmentation model with [preprocessing layers for image augmentation](https://www.tensorflow.org/guide/keras/preprocessing_layers#image_data_augmentation). This will transform the data during training to introduce variations of the same image. Let's quickly go over the layers you will use in this exercise.
#
# * [RandomFlip](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomFlip) is for randomly flipping the images horizontally, vertically, or both.
# * [RandomRotation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomRotation) rotates the image by an angle within a given range.
# * [RandomTranslation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomTranslation) shifts pictures vertically and horizontally.
# * [RandomZoom](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomZoom) zooms into or out of the images.
#
# In addition, some of these layers have a `fill_mode` parameter. This is the strategy used for filling newly created pixels, which can appear after a rotation or a width/height shift.
#
# The code below will create this model with some set parameters. After you complete this lab, feel free to modify these and see the impact on the results.

# %%
# Define fill mode.
FILL_MODE = 'nearest'

# Create the augmentation model.
data_augmentation = tf.keras.Sequential([
    # Specify the input shape.
    tf.keras.Input(shape=(150,150,3)),
    # Add the augmentation layers
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2, fill_mode=FILL_MODE),
    tf.keras.layers.RandomTranslation(0.2,0.2, fill_mode=FILL_MODE),
    tf.keras.layers.RandomZoom(0.2, fill_mode=FILL_MODE)
    ])

# %% [markdown]
# You will define a utility function that lets you preview how the transformed images look like. It will take in a sample image, then output a given number of augmented images using the model you defined above.

# %%
def demo_augmentation(sample_image, model, num_aug):
    '''Takes a single image array, then uses a model to generate num_aug transformations'''

    # Instantiate preview list
    image_preview = []

    # Convert input image to a PIL image instance
    sample_image_pil = tf.keras.utils.array_to_img(sample_image)

    # Append the result to the list
    image_preview.append(sample_image_pil)

    # Apply the image augmentation and append the results to the list
    for i in range(NUM_AUG):
        sample_image_aug = model(tf.expand_dims(sample_image, axis=0))
        sample_image_aug_pil = tf.keras.utils.array_to_img(tf.squeeze(sample_image_aug))
        image_preview.append(sample_image_aug_pil)

    # Instantiate a subplot
    fig, axes = plt.subplots(1, NUM_AUG + 1, figsize=(12, 12))

    # Preview the images.
    for index, ax in enumerate(axes):
        ax.imshow(image_preview[index])
        ax.set_axis_off()

        if index == 0:
            ax.set_title('original')
        else:
            ax.set_title(f'augment {index}')

# %% [markdown]
# Now get some images from the dataset.

# %%
# Get a batch of images
sample_batch = list(train_dataset.take(1))[0][0]
print(f'images per batch: {len(sample_batch)}')
# Out:
# images per batch: 20

# %% [markdown]
# This will show sample transformations for the first 4 images of the sample batch. Notice that each call of the `data_augmentation` model yields a different output. It's like adding more images to your dataset without you having to collect them manually.

# %%
NUM_AUG = 4

# Apply the transformations to the first 4 images
demo_augmentation(sample_batch[0], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[1], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[2], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[3], data_augmentation, NUM_AUG)

# Uncomment the line below to delete the variable to free up some memory
# del sample_batch

# %% [markdown]
# Now that you see what the preprocessing layers do, you can prepend these to the base model so it can generate transformed images to the base model. Do note that these layers are only active while training. They are automatically disabled during prediction and evaluation.

# %%
# Instantiate the base model
model_without_aug = create_model()

# Prepend the data augmentation layers to the base model
model_with_aug = tf.keras.models.Sequential([
    data_augmentation,
    model_without_aug
])

# Compile the model
model_with_aug.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
    metrics=['accuracy'])

# %% [markdown]
# Because you now have virtually more data, it will also take the model more time to learn the relevant features. Without data augmentation, your model already started overfitting to the training set within 20 epochs. Try training this model for 80 epochs and observe the results.

# %%
EPOCHS=80

# Train the new model
history_with_aug = model_with_aug.fit(
      train_dataset_final,
      epochs=EPOCHS,
      validation_data=validation_dataset_final,
      verbose=2)
# Out:
# Epoch 1/80
# 100/100 - 4s - 38ms/step - accuracy: 0.5090 - loss: 0.6951 - val_accuracy: 0.5260 - val_loss: 0.6913
# Epoch 2/80
# 100/100 - 1s - 10ms/step - accuracy: 0.5160 - loss: 0.6922 - val_accuracy: 0.5020 - val_loss: 0.6944
# Epoch 3/80
# 100/100 - 1s - 10ms/step - accuracy: 0.5290 - loss: 0.6908 - val_accuracy: 0.5620 - val_loss: 0.6862
# Epoch 4/80
# 100/100 - 1s - 10ms/step - accuracy: 0.5505 - loss: 0.6874 - val_accuracy: 0.5030 - val_loss: 0.6914
# Epoch 5/80
# 100/100 - 1s - 10ms/step - accuracy: 0.5665 - loss: 0.6794 - val_accuracy: 0.6260 - val_loss: 0.6654
# Epoch 6/80
# 100/100 - 1s - 10ms/step - accuracy: 0.5755 - loss: 0.6734 - val_accuracy: 0.6370 - val_loss: 0.6506
# Epoch 7/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6050 - loss: 0.6679 - val_accuracy: 0.6210 - val_loss: 0.6526
# Epoch 8/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6115 - loss: 0.6610 - val_accuracy: 0.6450 - val_loss: 0.6394
# Epoch 9/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6030 - loss: 0.6496 - val_accuracy: 0.5860 - val_loss: 0.6566
# Epoch 10/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6365 - loss: 0.6427 - val_accuracy: 0.6370 - val_loss: 0.6290
# Epoch 11/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6515 - loss: 0.6290 - val_accuracy: 0.6830 - val_loss: 0.6115
# Epoch 12/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6585 - loss: 0.6254 - val_accuracy: 0.6650 - val_loss: 0.6032
# Epoch 13/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6520 - loss: 0.6216 - val_accuracy: 0.6760 - val_loss: 0.5914
# Epoch 14/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6635 - loss: 0.6134 - val_accuracy: 0.6410 - val_loss: 0.6056
# Epoch 15/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6575 - loss: 0.6156 - val_accuracy: 0.6970 - val_loss: 0.5749
# Epoch 16/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6735 - loss: 0.6059 - val_accuracy: 0.6810 - val_loss: 0.5798
# Epoch 17/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6725 - loss: 0.6004 - val_accuracy: 0.6510 - val_loss: 0.6099
# Epoch 18/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6750 - loss: 0.5917 - val_accuracy: 0.6300 - val_loss: 0.6413
# Epoch 19/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6725 - loss: 0.5984 - val_accuracy: 0.7070 - val_loss: 0.5592
# Epoch 20/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6855 - loss: 0.5864 - val_accuracy: 0.5950 - val_loss: 0.7136
# Epoch 21/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6790 - loss: 0.5896 - val_accuracy: 0.6920 - val_loss: 0.5717
# Epoch 22/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6835 - loss: 0.5875 - val_accuracy: 0.7010 - val_loss: 0.5673
# Epoch 23/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6855 - loss: 0.5825 - val_accuracy: 0.6470 - val_loss: 0.6136
# Epoch 24/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6880 - loss: 0.5818 - val_accuracy: 0.6760 - val_loss: 0.5873
# Epoch 25/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6740 - loss: 0.5897 - val_accuracy: 0.7040 - val_loss: 0.5593
# Epoch 26/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6955 - loss: 0.5697 - val_accuracy: 0.6880 - val_loss: 0.5743
# Epoch 27/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6885 - loss: 0.5783 - val_accuracy: 0.7040 - val_loss: 0.5480
# Epoch 28/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6990 - loss: 0.5628 - val_accuracy: 0.6990 - val_loss: 0.5454
# Epoch 29/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7090 - loss: 0.5624 - val_accuracy: 0.6940 - val_loss: 0.5617
# Epoch 30/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7145 - loss: 0.5547 - val_accuracy: 0.7010 - val_loss: 0.5766
# Epoch 31/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6915 - loss: 0.5684 - val_accuracy: 0.6900 - val_loss: 0.5529
# Epoch 32/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7120 - loss: 0.5619 - val_accuracy: 0.7170 - val_loss: 0.5396
# Epoch 33/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7080 - loss: 0.5563 - val_accuracy: 0.7240 - val_loss: 0.5272
# Epoch 34/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7175 - loss: 0.5584 - val_accuracy: 0.7200 - val_loss: 0.5304
# Epoch 35/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7190 - loss: 0.5529 - val_accuracy: 0.7300 - val_loss: 0.5299
# Epoch 36/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7110 - loss: 0.5481 - val_accuracy: 0.7160 - val_loss: 0.5260
# Epoch 37/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7260 - loss: 0.5475 - val_accuracy: 0.7290 - val_loss: 0.5243
# Epoch 38/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7210 - loss: 0.5488 - val_accuracy: 0.7370 - val_loss: 0.5164
# Epoch 39/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7260 - loss: 0.5435 - val_accuracy: 0.7020 - val_loss: 0.5476
# Epoch 40/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7250 - loss: 0.5352 - val_accuracy: 0.7130 - val_loss: 0.5280
# Epoch 41/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7300 - loss: 0.5331 - val_accuracy: 0.7450 - val_loss: 0.5126
# Epoch 42/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7245 - loss: 0.5392 - val_accuracy: 0.7330 - val_loss: 0.5212
# Epoch 43/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7265 - loss: 0.5397 - val_accuracy: 0.6890 - val_loss: 0.5492
# Epoch 44/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7285 - loss: 0.5285 - val_accuracy: 0.6450 - val_loss: 0.6286
# Epoch 45/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7380 - loss: 0.5270 - val_accuracy: 0.7390 - val_loss: 0.5150
# Epoch 46/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7200 - loss: 0.5359 - val_accuracy: 0.7380 - val_loss: 0.5037
# Epoch 47/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7410 - loss: 0.5231 - val_accuracy: 0.7410 - val_loss: 0.5060
# Epoch 48/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7365 - loss: 0.5231 - val_accuracy: 0.7120 - val_loss: 0.5408
# Epoch 49/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7445 - loss: 0.5135 - val_accuracy: 0.7530 - val_loss: 0.4952
# Epoch 50/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7385 - loss: 0.5215 - val_accuracy: 0.7370 - val_loss: 0.5234
# Epoch 51/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7390 - loss: 0.5208 - val_accuracy: 0.7270 - val_loss: 0.5167
# Epoch 52/80
# 100/100 - 1s - 11ms/step - accuracy: 0.7350 - loss: 0.5203 - val_accuracy: 0.7400 - val_loss: 0.5129
# Epoch 53/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7370 - loss: 0.5281 - val_accuracy: 0.7470 - val_loss: 0.5112
# Epoch 54/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7470 - loss: 0.5109 - val_accuracy: 0.7210 - val_loss: 0.5410
# Epoch 55/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7505 - loss: 0.5133 - val_accuracy: 0.7630 - val_loss: 0.4875
# Epoch 56/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7515 - loss: 0.5077 - val_accuracy: 0.7490 - val_loss: 0.5083
# Epoch 57/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7395 - loss: 0.5215 - val_accuracy: 0.7400 - val_loss: 0.5013
# Epoch 58/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7350 - loss: 0.5181 - val_accuracy: 0.7180 - val_loss: 0.5347
# Epoch 59/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7385 - loss: 0.5047 - val_accuracy: 0.7070 - val_loss: 0.5407
# Epoch 60/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7530 - loss: 0.5048 - val_accuracy: 0.7550 - val_loss: 0.4955
# Epoch 61/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7375 - loss: 0.5086 - val_accuracy: 0.7500 - val_loss: 0.4917
# Epoch 62/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7575 - loss: 0.5000 - val_accuracy: 0.7670 - val_loss: 0.4686
# Epoch 63/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7590 - loss: 0.5007 - val_accuracy: 0.7560 - val_loss: 0.4814
# Epoch 64/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7545 - loss: 0.5003 - val_accuracy: 0.7370 - val_loss: 0.5131
# Epoch 65/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7680 - loss: 0.5038 - val_accuracy: 0.7680 - val_loss: 0.4924
# Epoch 66/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7555 - loss: 0.4865 - val_accuracy: 0.7540 - val_loss: 0.4907
# Epoch 67/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7550 - loss: 0.4979 - val_accuracy: 0.7590 - val_loss: 0.4895
# Epoch 68/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7565 - loss: 0.4921 - val_accuracy: 0.7510 - val_loss: 0.4900
# Epoch 69/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7695 - loss: 0.4843 - val_accuracy: 0.7700 - val_loss: 0.4797
# Epoch 70/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7630 - loss: 0.4926 - val_accuracy: 0.7440 - val_loss: 0.4957
# Epoch 71/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7650 - loss: 0.4822 - val_accuracy: 0.7570 - val_loss: 0.4808
# Epoch 72/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7745 - loss: 0.4829 - val_accuracy: 0.7720 - val_loss: 0.4813
# Epoch 73/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7655 - loss: 0.4837 - val_accuracy: 0.7660 - val_loss: 0.4874
# Epoch 74/80
# 100/100 - 1s - 11ms/step - accuracy: 0.7685 - loss: 0.4766 - val_accuracy: 0.7560 - val_loss: 0.4849
# Epoch 75/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7555 - loss: 0.4948 - val_accuracy: 0.7190 - val_loss: 0.5444
# Epoch 76/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7735 - loss: 0.4689 - val_accuracy: 0.7670 - val_loss: 0.4705
# Epoch 77/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7765 - loss: 0.4797 - val_accuracy: 0.7580 - val_loss: 0.4790
# Epoch 78/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7645 - loss: 0.4741 - val_accuracy: 0.7660 - val_loss: 0.4739
# Epoch 79/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7735 - loss: 0.4779 - val_accuracy: 0.7370 - val_loss: 0.5006
# Epoch 80/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7730 - loss: 0.4785 - val_accuracy: 0.7590 - val_loss: 0.4836

# %%
# Plot the results of training with data augmentation
plot_loss_acc(history_with_aug)

# %% [markdown]
# As you can see, the training accuracy has gone down compared to the baseline. This is expected because (as a result of data augmentation) there are more variety in the images so the model will need more runs to learn from them. The good thing is the validation accuracy is no longer stalling and is more in line with the training results. This means that the model is now performing better on unseen data.

# %% [markdown]
# ## Wrap Up
#
# This exercise showed a simple trick to avoid overfitting. You can improve your baseline results by simply tweaking the same images you have already. The image augmentation preprocessing layers will do just that. Try to modify the values in the augmentation model and see what results you get. You can also add other preprocessing layers for random contrast, brightness, or cropping.
#
# Take note that this will not work for all cases. In the next lesson, Laurence will show a scenario where data augmentation will not help improve your validation accuracy.
#
# Before going back to the classroom, run the cell below to free up resources for the next lab. You might see a pop-up about restarting the kernel afterwards. You can safely ignore it and just press Ok. You can then close this lab, then go back to the classroom for the next lecture. See you there!

# %%
# Shutdown the kernel to free up resources. 
# Note: You can expect a pop-up when you run this cell. You can safely ignore that and just press `Ok`.

from IPython import get_ipython

k = get_ipython().kernel

k.do_shutdown(restart=False)
# Out:
# {'status': 'ok', 'restart': False}
